# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/AI-DS/headbrain.csv")
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
x = df["Head Size(cm^3)"].tolist()
y = df["Brain Weight(grams)"].tolist()

# %%
x
# Out:
# [4512,
#  3738,
#  4261,
#  3777,
#  4177,
#  3585,
#  3785,
#  3559,
#  3613,
#  3982,
#  3443,
#  3993,
#  3640,
#  4208,
#  3832,
#  3876,
#  3497,
#  3466,
#  3095,
#  4424,
#  3878,
#  4046,
#  3804,
#  3710,
#  4747,
#  4423,
#  4036,
#  4022,
#  3454,
#  4175,
#  3787,
#  3796,
#  4103,
#  4161,
#  4158,
#  3814,
#  3527,
#  3748,
#  3334,
#  3492,
#  3962,
#  3505,
#  4315,
#  3804,
#  3863,
#  4034,
#  4308,
#  3165,
#  3641,
#  3644,
#  3891,
#  3793,
#  4270,
#  4063,
#  4012,
#  3458,
#  3890,
#  4166,
#  3935,
#  3669,
#  3866,
#  3393,
#  4442,
#  4253,
#  3727,
#  3329,
#  3415,
#  3372,
#  4430,
#  4381,
#  4008,
#  3858,
#  4121,
#  4057,
#  3824,
#  3394,
#  3558,
#  3362,
#  3930,
#  3835,
#  3830,
#  3856,
#  3249,
#  3577,
#  3933,
#  3850,
#  3309,
#  3406,
#  3506,
#  3907,
#  4160,
#  3318,
#  3662,
#  3899,
#  3700,
#  3779,
#  3473,
#  3490,
#  3654,
#  3478,
#  3495,
#  3834,
#  3876,
#  3661,
#  3618,
#  3648,
#  4032,
#  3399,
#  3916,
#  4430,
#  3695,
# ...

# %%
y
# Out:
# [1530,
#  1297,
#  1335,
#  1282,
#  1590,
#  1300,
#  1400,
#  1255,
#  1355,
#  1375,
#  1340,
#  1380,
#  1355,
#  1522,
#  1208,
#  1405,
#  1358,
#  1292,
#  1340,
#  1400,
#  1357,
#  1287,
#  1275,
#  1270,
#  1635,
#  1505,
#  1490,
#  1485,
#  1310,
#  1420,
#  1318,
#  1432,
#  1364,
#  1405,
#  1432,
#  1207,
#  1375,
#  1350,
#  1236,
#  1250,
#  1350,
#  1320,
#  1525,
#  1570,
#  1340,
#  1422,
#  1506,
#  1215,
#  1311,
#  1300,
#  1224,
#  1350,
#  1335,
#  1390,
#  1400,
#  1225,
#  1310,
#  1560,
#  1330,
#  1222,
#  1415,
#  1175,
#  1330,
#  1485,
#  1470,
#  1135,
#  1310,
#  1154,
#  1510,
#  1415,
#  1468,
#  1390,
#  1380,
#  1432,
#  1240,
#  1195,
#  1225,
#  1188,
#  1252,
#  1315,
#  1245,
#  1430,
#  1279,
#  1245,
#  1309,
#  1412,
#  1120,
#  1220,
#  1280,
#  1440,
#  1370,
#  1192,
#  1230,
#  1346,
#  1290,
#  1165,
#  1240,
#  1132,
#  1242,
#  1270,
#  1218,
#  1430,
#  1588,
#  1320,
#  1290,
#  1260,
#  1425,
#  1226,
#  1360,
#  1620,
#  1310,
# ...

# %%
x_head_mean = np.mean(x)
y_brain_mean = np.mean(y)

# %%
x_head_mean
# Out:
# np.float64(3633.9915611814345)

# %%
y_brain_mean
# Out:
# np.float64(1282.873417721519)

# %%
for num in range(len(x)):
    sum = sum+
